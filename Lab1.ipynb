# %% [markdown]
# ## Lab.1 - Preparação de Ambiente
# * Instalação do python e variáveis de ambiente
# * Criação do venv
# * Instalação de bibliotecas: pandas, seaborn
# * Configuração do VSCode com EXTENSÕES

# %% [markdown]
# ### Criar o anbiente

# %%
python -m venv venv

# %% [markdown]
# ### Ativar o ambiente

# %%
import seaborn as sns 

import matplotlib as plt 

df = sns.load_dataset("penguins") 

sns.jointplot(data=df, x="flipper_length_mm", y="bill_length_mm", hue="species")
