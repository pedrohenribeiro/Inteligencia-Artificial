# %% [markdown]
# ## Lab.1 - Preparação de Ambiente
# * Instalação do python e variáveis de ambiente
# * Criação do venv
# * Instalação de bibliotecas: pandas, seaborn
# * Configuração do VSCode com EXTENSÕES

# %% [markdown]
# ### Criar o anbiente

# %%
python -m venv venv

# %% [markdown]
# ### Ativar o ambiente

# %%
import seaborn as sns
import matplotlib as plt
df = sns.load_dataset("penguins")
sns.jointplot(data=df, x="flipper_lenght_mm", y="bill_lenght_mm", hue="species")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 4
#       2 import matplotlib as plt
#       3 df = sns.load_dataset("penguins")
# ----> 4 sns.jointplot(data=df, x="flipper_lenght_mm", y="bill_lenght_mm", hue="species")
#
# File c:\Users\pedro\Desktop\InteligenciaArtificial\venv\Lib\site-packages\seaborn\axisgrid.py:2243, in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2240     dropna = True
#    2242 # Initialize the JointGrid object
# -> 2243 grid = JointGrid(
#    2244     data=data, x=x, y=y, hue=hue,
#    2245     palette=palette, hue_order=hue_order, hue_norm=hue_norm,
#    2246     dropna=dropna, height=height, ratio=ratio, space=space,
#    2247     xlim=xlim, ylim=ylim, marginal_ticks=marginal_ticks,
#    2248 )
# ...
